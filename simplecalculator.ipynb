# %%
from tkinter import*
window=Tk()
window.title('simple calculator')
window.geometry ('300x300')


def click():
    print(entry1.insert(END,number))
    
def C():
    entry1.delete(0,END)
    
    
def AC():
    a=entry1.get()
    length=len(a)
    entry1.delete(length-1,END)
    
    
def operation():
    while True:
        global e
        m=entry1.get()
        r=str(m)
        w=eval(r)
        e=('=',w)
        return e
    
    
def final():
    global e
    operation()
    entry1.insert(END,e)

    
def error():
    try:
        final()
    except:
        clear()
        entry1.insert(END,'syntax error')
    


button1=Button(window,width=5,height=0,text='C',font=('arial',15,'bold'),fg='black',bg='blue',command=C).place(x=1,y=51)
button2=Button(window,width=5,height=0,text='/',font=('arial',15,'bold'),fg='white',bg='black',command=lambda:entry1.insert(END,'/')).place(x=78,y=51)
button3=Button(window,width=5,height=0,text='%',font=('arial',15,'bold'),fg='white',bg='black',command=lambda:entry1.insert(END,'%')).place(x=153,y=51)
button4=Button(window,width=5,height=0,text='*',font=('arial',15,'bold'),fg='white',bg='black',command=lambda:entry1.insert(END,'*')).place(x=230,y=51)


button5=Button(window,width=5,height=0,text='7',font=('arial',15,'bold'),fg='white',bg='black',command=lambda:entry1.insert(END,'7')).place(x=1,y=100)
button6=Button(window,width=5,height=0,text='8',font=('arial',15,'bold'),fg='white',bg='black',command=lambda:entry1.insert(END,'8')).place(x=78,y=100)
button7=Button(window,width=5,height=0,text='9',font=('arial',15,'bold'),fg='white',bg='black',command=lambda:entry1.insert(END,'9')).place(x=153,y=100)
button8=Button(window,width=5,height=0,text='-',font=('arial',15,'bold'),fg='white',bg='black',command=lambda:entry1.insert(END,'-')).place(x=230,y=100)


button9 =Button(window,width=5,height=0,text='4',font=('arial',15,'bold'),fg='white',bg='black',command=lambda:entry1.insert(END,'4')).place(x=1,y=150)
button10=Button(window,width=5,height=0,text='5',font=('arial',15,'bold'),fg='white',bg='black',command=lambda:entry1.insert(END,'5')).place(x=78,y=150)
button11=Button(window,width=5,height=0,text='6',font=('arial',15,'bold'),fg='white',bg='black',command=lambda:entry1.insert(END,'6')).place(x=153,y=150)
button12=Button(window,width=5,height=0,text='+',font=('arial',15,'bold'),fg='white',bg='black',command=lambda:entry1.insert(END,"+")).place(x=230,y=150)


button13=Button(window,width=5,height=0,text='1',font=('arial',15,'bold'),fg='white',bg='black',command=lambda:entry1.insert(END,'1')).place(x=1,y=200)
button14=Button(window,width=5,height=0,text='2',font=('arial',15,'bold'),fg='white',bg='black',command=lambda:entry1.insert(END,'2')).place(x=78,y=200)
button15=Button(window,width=5,height=0,text='3',font=('arial',15,'bold'),fg='white',bg='black',command=lambda:entry1.insert(END,'3')).place(x=153,y=200)


button16=Button(window,width=5,height=0,text='0',font=('arial',15,'bold'),fg='white',bg='black',command=lambda:entry1.insert(END,'0')).place(x=1,y=250)
button17=Button(window,width=5,height=0,text='.',font=('arial',15,'bold'),fg='white',bg='black',command=lambda:entry1.insert(END,'.')).place(x=78,y=250)
button18=Button(window,width=5,height=0,text='AC',font=('arial',15,'bold'),fg='white',bg='blue',command=AC).place(x=153,y=250)


button19=Button(window,width=5,height=3,text='=',font=('arial',15,'bold'),fg='white',bg='black',command=error).place(x=230,y=200)



entry1=Entry(window,fg='white',bg='grey',font=('arial',30))
entry1.place(x=0,y=0,width=300,height=50)
window.configure(bg='black')

window.mainloop()
